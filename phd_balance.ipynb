# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_state_qsphere

# %%
mycircuit = QuantumCircuit(1)
mycircuit.reset(0)
mycircuit.draw()

# %%
plot_state_qsphere(Statevector.from_instruction(mycircuit))

# %%
mycircuit = QuantumCircuit(1)
mycircuit.reset(0)
mycircuit.h(0)
mycircuit.draw()

# %%
plot_state_qsphere(Statevector.from_instruction(mycircuit))

# %%
mycircuit = QuantumCircuit(1)
mycircuit.reset(0)
mycircuit.x(0)
mycircuit.draw()

# %%
plot_state_qsphere(Statevector.from_instruction(mycircuit))

# %%
mycircuit = QuantumCircuit(1)
mycircuit.reset(0)
mycircuit.x(0)
mycircuit.h(0)
mycircuit.draw()

# %%
plot_state_qsphere(Statevector.from_instruction(mycircuit))

# %%
mycircuit = QuantumCircuit(1)
mycircuit.reset(0)
mycircuit.h(0)
mycircuit.h(0)
mycircuit.draw()

# %%
plot_state_qsphere(Statevector.from_instruction(mycircuit))

# %%
mycircuit = QuantumCircuit(1)
mycircuit.reset(0)
mycircuit.h(0)
mycircuit.measure_all()

from qiskit import IBMQ, execute
from qiskit.tools.monitor import job_monitor
quantum_computer = IBMQ.load_account().get_backend('ibmq_ourense')
job = execute(mycircuit, backend=quantum_computer, shots = 1000)
job_monitor(job)
counts = job.result().get_counts()
print(counts)
# Out:
# /Users/abraham.asfawibm.com/anaconda3/envs/qiskitdevl/lib/python3.8/site-packages/qiskit/providers/ibmq/ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '
# Job Status: job has successfully run
# {'0': 533, '1': 467}

# %%
from qiskit.visualization import plot_histogram
plot_histogram(counts)
